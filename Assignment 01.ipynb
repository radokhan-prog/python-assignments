# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("rado khan \n beebarg \n 13-11-2007")
# Out:
# rado khan
#  beebarg
#  13-11-2007

# %% [markdown]
# b/2. Write your small bio using variables and print it using print function

# %%
my_bio = """my name is rado khan
          im very happpy and motivated to learn python with sir hussain

          and in coming months i beleive that i will make my place in the tech industry in future"""
print = my_bio

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
5-5
5+3
8*5
9/7
9//6
6%6
# Out:
# 0

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = 65
maths = 76
islamiat  = 98
total_marks = 300
marks_obtain = english + maths + islamiat + total_marks
percentage = marks_obtain / total_marks * 100
